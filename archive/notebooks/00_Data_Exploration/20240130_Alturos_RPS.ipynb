# %%
import pandas as pd
#Open ths csv file in read mode
with open('/content/v5_20230409_090939_206m.csv', mode='r')as file:
  df_206=pd.read_csv(file,sep=',')
#print the first five rows of the data
print(df_206.head(5))
# Out:
#                   Timestamp  accelX(g)  accelY(g)  accelZ(g)  accelUserX(g)  \
# 0  09-Apr-2023 09:09:39.979    -0.0725    -0.9272    -0.7220        -0.0473
# 1  09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220        -0.0249
# 2  09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220        -0.0249
# 3  09-Apr-2023 09:09:39.985     0.0197    -1.0018    -0.5080        -0.0239
# 4  09-Apr-2023 09:09:39.996     0.1890    -1.0938    -0.3944         0.1304
#
#    accelUserY(g)  accelUserZ(g)  gyroX(rad/s)  gyroY(rad/s)  gyroZ(rad/s)  \
# 0         0.0011        -0.4685       -0.3570        0.0006       -0.3407
# 1        -0.0319        -0.2194        0.6848       -0.6088       -0.1956
# 2        -0.0319        -0.2194        0.6848       -0.6088       -0.1956
# 3        -0.0306        -0.2227        0.6996       -0.8581       -0.0679
# 4        -0.1245        -0.0687        0.6565       -1.0381        0.1358
#
# ...

# %%
df_206.info
# Out:
# <bound method DataFrame.info of                         Timestamp  accelX(g)  accelY(g)  accelZ(g)  \
# 0        09-Apr-2023 09:09:39.979    -0.0725    -0.9272    -0.7220
# 1        09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220
# 2        09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220
# 3        09-Apr-2023 09:09:39.985     0.0197    -1.0018    -0.5080
# 4        09-Apr-2023 09:09:39.996     0.1890    -1.0938    -0.3944
# ...                           ...        ...        ...        ...
# 1232542  09-Apr-2023 12:35:52.580     0.2053    -0.4362    -0.7583
# 1232543  09-Apr-2023 12:35:52.589     0.1908    -0.4307    -0.8224
# 1232544  09-Apr-2023 12:35:52.600     0.2315    -0.4145    -0.8721
# 1232545  09-Apr-2023 12:35:52.610     0.2623    -0.3946    -0.9105
# 1232546  09-Apr-2023 12:35:52.620     0.2395    -0.4255    -0.9398
#
#          accelUserX(g)  accelUserY(g)  accelUserZ(g)  gyroX(rad/s)  \
# ...

# %%
df_206.shape
# Out:
# (1232547, 44)

# %%
# df_206.shape after the drop the duplicates

# %%
df_206.iloc

# %%
df_206.columns
# Out:
# Index(['Timestamp', 'accelX(g)', 'accelY(g)', 'accelZ(g)', 'accelUserX(g)',
#        'accelUserY(g)', 'accelUserZ(g)', 'gyroX(rad/s)', 'gyroY(rad/s)',
#        'gyroZ(rad/s)', 'Roll(rads)', 'Pitch(rads)', 'Yaw(rads)', 'm11', 'm12',
#        'm13', 'm21', 'm22', 'm23', 'm31', 'm32', 'm33', 'qX', 'qY', 'qZ', 'qW',
#        'Lat', 'Long', 'Speed(m/s)', 'TrueHeading', 'Alt(m)',
#        'HorizontalAccuracy(m)', 'VerticalAccuracy(m)', 'Course',
#        'ActivityType', 'ActivityConfidence', 'Pressure(kilopascals)',
#        'RelativeAltitude(meters)', 'magX(µT)', 'magY(µT)', 'magZ(µT)',
#        'calMagX(µT)', 'calMagY(µT)', 'calMagZ(µT)'],
#       dtype='object')

# %%
duplicates = df_206[df_206.duplicated()]

# Print the duplicate rows
print("Duplicate Rows:")
print(duplicates)
# Out:
# Duplicate Rows:
#                         Timestamp  accelX(g)  accelY(g)  accelZ(g)  \
# 504      09-Apr-2023 09:09:45.013    -0.3849    -0.5468     1.4922
# 525      09-Apr-2023 09:09:45.424    -0.6690    -0.8205     0.8036
# 526      09-Apr-2023 09:09:45.424    -0.6690    -0.8205     0.8036
# 529      09-Apr-2023 09:09:45.425    -0.6418    -0.7451     0.7681
# 530      09-Apr-2023 09:09:45.425    -0.6418    -0.7451     0.7681
# ...                           ...        ...        ...        ...
# 1165428  09-Apr-2023 12:24:38.848     0.0139    -0.8214     0.1669
# 1198374  09-Apr-2023 12:30:09.619     0.1298    -0.8134     0.1304
# 1198375  09-Apr-2023 12:30:09.619     0.1298    -0.8134     0.1304
# 1198377  09-Apr-2023 12:30:09.620     0.1298    -0.8134     0.1304
# 1198378  09-Apr-2023 12:30:09.620     0.1298    -0.8134     0.1304
#
#          accelUserX(g)  accelUserY(g)  accelUserZ(g)  gyroX(rad/s)  \
# 504             0.2134         0.2101         0.9702        1.4494
# ...

# %%
# Remove duplicate rows
df_206 = df_206.drop_duplicates()

# Verify that duplicates are removed
print("DataFrame after removing duplicates:")
print(df_206.head())
# Out:
# DataFrame after removing duplicates:
#                   Timestamp  accelX(g)  accelY(g)  accelZ(g)  accelUserX(g)  \
# 0  09-Apr-2023 09:09:39.979    -0.0725    -0.9272    -0.7220        -0.0473
# 1  09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220        -0.0249
# 2  09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220        -0.0249
# 3  09-Apr-2023 09:09:39.985     0.0197    -1.0018    -0.5080        -0.0239
# 4  09-Apr-2023 09:09:39.996     0.1890    -1.0938    -0.3944         0.1304
#
#    accelUserY(g)  accelUserZ(g)  gyroX(rad/s)  gyroY(rad/s)  gyroZ(rad/s)  \
# 0         0.0011        -0.4685       -0.3570        0.0006       -0.3407
# 1        -0.0319        -0.2194        0.6848       -0.6088       -0.1956
# 2        -0.0319        -0.2194        0.6848       -0.6088       -0.1956
# 3        -0.0306        -0.2227        0.6996       -0.8581       -0.0679
# 4        -0.1245        -0.0687        0.6565       -1.0381        0.1358
#
# ...

# %%
df_206
# Out:
#                         Timestamp  accelX(g)  accelY(g)  accelZ(g)  \
# 0        09-Apr-2023 09:09:39.979    -0.0725    -0.9272    -0.7220
# 1        09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220
# 2        09-Apr-2023 09:09:39.981    -0.0725    -0.9272    -0.7220
# 3        09-Apr-2023 09:09:39.985     0.0197    -1.0018    -0.5080
# 4        09-Apr-2023 09:09:39.996     0.1890    -1.0938    -0.3944
# ...                           ...        ...        ...        ...
# 1232542  09-Apr-2023 12:35:52.580     0.2053    -0.4362    -0.7583
# 1232543  09-Apr-2023 12:35:52.589     0.1908    -0.4307    -0.8224
# 1232544  09-Apr-2023 12:35:52.600     0.2315    -0.4145    -0.8721
# 1232545  09-Apr-2023 12:35:52.610     0.2623    -0.3946    -0.9105
# 1232546  09-Apr-2023 12:35:52.620     0.2395    -0.4255    -0.9398
#
#          accelUserX(g)  accelUserY(g)  accelUserZ(g)  gyroX(rad/s)  \
# 0              -0.0473         0.0011        -0.4685       -0.3570
# ...

# %%
df_206.corr()
# Out:
# <ipython-input-15-29c6eae348fb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_206.corr()
#                           accelX(g)  accelY(g)  accelZ(g)  accelUserX(g)  \
# accelX(g)                  1.000000   0.024851  -0.128089       0.530223
# accelY(g)                  0.024851   1.000000  -0.714038      -0.058151
# accelZ(g)                 -0.128089  -0.714038   1.000000       0.051847
# accelUserX(g)              0.530223  -0.058151   0.051847       1.000000
# accelUserY(g)             -0.104097   0.456522   0.098043      -0.117149
# accelUserZ(g)              0.149572   0.109659   0.202327       0.316430
# gyroX(rad/s)               0.011847   0.001873  -0.014781       0.000245
# gyroY(rad/s)               0.126307   0.010568   0.024652       0.292390
# ...

# %%
df_206['ActivityType'].value_counts()
# Out:
# Unknown       699933
# Stationary    306615
# Walking       118237
# Cycling       105275
# Automotive      2304
# Name: ActivityType, dtype: int64

# %%
df_206['Timestamp'].value_counts()
# Out:
# 09-Apr-2023 11:52:06.230    3
# 09-Apr-2023 11:52:06.284    2
# 09-Apr-2023 10:34:09.391    2
# 09-Apr-2023 10:00:41.400    2
# 09-Apr-2023 09:50:39.104    2
#                            ..
# 09-Apr-2023 10:18:23.692    1
# 09-Apr-2023 10:18:23.682    1
# 09-Apr-2023 10:18:23.672    1
# 09-Apr-2023 10:18:23.662    1
# 09-Apr-2023 12:35:52.620    1
# Name: Timestamp, Length: 1232312, dtype: int64

# %%
df_206['Timestamp']
# Out:
# 0          09-Apr-2023 09:09:39.979
# 1          09-Apr-2023 09:09:39.981
# 2          09-Apr-2023 09:09:39.981
# 3          09-Apr-2023 09:09:39.985
# 4          09-Apr-2023 09:09:39.996
#                      ...
# 1232542    09-Apr-2023 12:35:52.580
# 1232543    09-Apr-2023 12:35:52.589
# 1232544    09-Apr-2023 12:35:52.600
# 1232545    09-Apr-2023 12:35:52.610
# 1232546    09-Apr-2023 12:35:52.620
# Name: Timestamp, Length: 1232364, dtype: object

# %%
# Convert 'Timestamp' column to datetime
df_206['Timestamp'] = pd.to_datetime(df_206['Timestamp'])

# Verify the changes
print(df_206.info())
# Out:
# <ipython-input-19-fd8704ba1e68>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_206['Timestamp'] = pd.to_datetime(df_206['Timestamp'])
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1232364 entries, 0 to 1232546
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   Timestamp                 1232364 non-null  datetime64[ns]
#  1   accelX(g)                 1232364 non-null  float64
#  2   accelY(g)                 1232364 non-null  float64
#  3   accelZ(g)                 1232364 non-null  float64
#  4   accelUserX(g)             1232364 non-null  float64
#  5   accelUserY(g)             1232364 non-null  float64
# ...

# %% [markdown]
# ##Line Plot of Timestamp vs. Accelerometer Readings:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 8))
plt.plot(df_206['Timestamp'], df_206['accelX(g)'], label='accelX(g)')
plt.plot(df_206['Timestamp'], df_206['accelY(g)'], label='accelY(g)')
plt.plot(df_206['Timestamp'], df_206['accelZ(g)'], label='accelZ(g)')
plt.title('Accelerometer Readings Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Acceleration (g)')
plt.legend()
plt.show()

# %% [markdown]
# ##Scatter Plot of Accelerometer vs. Gyroscope Readings:

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df_206['accelX(g)'], df_206['gyroX(rad/s)'], alpha=0.5, label='X-axis')
plt.scatter(df_206['accelY(g)'], df_206['gyroY(rad/s)'], alpha=0.5, label='Y-axis')
plt.scatter(df_206['accelZ(g)'], df_206['gyroZ(rad/s)'], alpha=0.5, label='Z-axis')
plt.title('Scatter Plot of Accelerometer vs. Gyroscope Readings')
plt.xlabel('Accelerometer Reading (g)')
plt.ylabel('Gyroscope Reading (rad/s)')
plt.legend()
plt.show()

# %% [markdown]
# ##Heatmap of Correlation Matrix:

# %%
import seaborn as sns

correlation_matrix = df_206.corr()
plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-22-aee46ee8b5ce>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_206.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix
correlation_matrix = df_206.corr()

# Filter correlations above 80%
high_corr_matrix = correlation_matrix[abs(correlation_matrix) > 0.8]

# Plot the heatmap
plt.figure(figsize=(18, 14))
sns.heatmap(high_corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap (Correlations above 80%)')
plt.show()
# Out:
# <ipython-input-23-eff3b5e46020>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_206.corr()

# %% [markdown]
# ##Box Plot of Activity Types and Pressure:

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='ActivityType', y='Pressure(kilopascals)', data=df_206)
plt.title('Box Plot of Activity Types and Pressure')
plt.show()

# %%
# Basic statistics of accelerometer readings
accel_stats = df_206[['accelX(g)', 'accelY(g)', 'accelZ(g)']].describe()
print("Accelerometer Statistics:")
print(accel_stats)
# Out:
# Accelerometer Statistics:
#           accelX(g)     accelY(g)     accelZ(g)
# count  1.232364e+06  1.232364e+06  1.232364e+06
# mean   2.537000e-02 -8.162166e-01 -9.468241e-02
# std    2.345784e-01  3.609701e-01  4.506782e-01
# min   -3.252600e+00 -5.943600e+00 -4.067700e+00
# 25%   -9.350000e-02 -9.848000e-01 -2.537000e-01
# 50%    7.400000e-03 -9.566000e-01  1.058000e-01
# 75%    1.296000e-01 -8.172000e-01  2.075000e-01
# max    3.100100e+00  2.750700e+00  3.027700e+00

# %%
import matplotlib.pyplot as plt

# Basic statistics of accelerometer readings
accel_stats = df_206[['accelX(g)', 'accelY(g)', 'accelZ(g)']].describe()

# Extract mean values
accel_mean_values = accel_stats.loc['mean']

# Plot the mean values
plt.figure(figsize=(10, 6))
accel_mean_values.plot(kind='bar', color=['red', 'green', 'blue'])
plt.title('Mean Accelerometer Readings')
plt.xlabel('Accelerometer Axis')
plt.ylabel('Mean Acceleration (g)')
plt.show()

# %%
# Correlation matrix between accelerometer and gyroscope readings
accel_gyro_corr = df_206[['accelX(g)', 'accelY(g)', 'accelZ(g)', 'gyroX(rad/s)', 'gyroY(rad/s)', 'gyroZ(rad/s)']].corr()
print("Correlation between Accelerometer and Gyroscope Readings:")
print(accel_gyro_corr)
# Out:
# Correlation between Accelerometer and Gyroscope Readings:
#               accelX(g)  accelY(g)  accelZ(g)  gyroX(rad/s)  gyroY(rad/s)  \
# accelX(g)      1.000000   0.024851  -0.128089      0.011847      0.126307
# accelY(g)      0.024851   1.000000  -0.714038      0.001873      0.010568
# accelZ(g)     -0.128089  -0.714038   1.000000     -0.014781      0.024652
# gyroX(rad/s)   0.011847   0.001873  -0.014781      1.000000     -0.009095
# gyroY(rad/s)   0.126307   0.010568   0.024652     -0.009095      1.000000
# gyroZ(rad/s)  -0.022549   0.007185  -0.016740      0.085367      0.034641
#
#               gyroZ(rad/s)
# accelX(g)        -0.022549
# accelY(g)         0.007185
# accelZ(g)        -0.016740
# gyroX(rad/s)      0.085367
# gyroY(rad/s)      0.034641
# gyroZ(rad/s)      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix between accelerometer and gyroscope readings
accel_gyro_corr = df_206[['accelX(g)', 'accelY(g)', 'accelZ(g)', 'gyroX(rad/s)', 'gyroY(rad/s)', 'gyroZ(rad/s)']].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(accel_gyro_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Accelerometer and Gyroscope Readings')
plt.show()

# %%
df_206.shape
# Out:
# (1232364, 44)

# %%
# Basic statistics of magnetic field readings
mag_stats = df_206[['magX(µT)', 'magY(µT)', 'magZ(µT)', 'calMagX(µT)', 'calMagY(µT)', 'calMagZ(µT)']].describe()
print("Magnetic Field Statistics:")
print(mag_stats)
# Out:
# Magnetic Field Statistics:
#            magX(µT)      magY(µT)      magZ(µT)   calMagX(µT)   calMagY(µT)  \
# count  1.232364e+06  1.232364e+06  1.232364e+06  1.232364e+06  1.232364e+06
# mean  -1.074556e+02 -7.941771e+01 -7.467543e+01  2.659003e+00 -2.271319e+01
# std    1.886987e+01  2.073997e+01  2.317236e+01  1.891878e+01  2.102855e+01
# min   -6.802279e+02 -1.612419e+02 -8.762844e+02 -5.696544e+02 -1.052183e+02
# 25%   -1.208303e+02 -9.263350e+01 -8.685820e+01 -9.969000e+00 -3.731420e+01
# 50%   -1.057708e+02 -8.599930e+01 -7.505310e+01  5.538100e+00 -2.905475e+01
# 75%   -9.440060e+01 -7.239110e+01 -6.143260e+01  1.497130e+01 -1.264760e+01
# max    3.888200e+01  8.172500e+01  3.596440e+01  1.471053e+02  1.364858e+02
#
#         calMagZ(µT)
# count  1.232364e+06
# mean  -2.312977e+00
# std    2.528604e+01
# min   -8.137221e+02
# 25%   -1.656610e+01
# 50%   -2.974400e+00
# 75%    1.054062e+01
# max    1.031260e+02

# %%
import matplotlib.pyplot as plt

# Basic statistics of magnetic field readings
mag_stats = df_206[['magX(µT)', 'magY(µT)', 'magZ(µT)', 'calMagX(µT)', 'calMagY(µT)', 'calMagZ(µT)']].describe()

# Extract mean values
mag_mean_values = mag_stats.loc['mean']

# Plot the mean values
plt.figure(figsize=(10, 6))
mag_mean_values.plot(kind='bar', color=['red', 'green', 'blue', 'orange', 'purple', 'brown'])
plt.title('Mean Magnetic Field Readings')
plt.xlabel('Magnetic Field Axis')
plt.ylabel('Mean Magnetic Field (µT)')
plt.show()

# %%
# Correlation matrix between magnetic field and calibrated magnetic field readings
mag_cal_corr = df_206[['magX(µT)', 'magY(µT)', 'magZ(µT)', 'calMagX(µT)', 'calMagY(µT)', 'calMagZ(µT)']].corr()
print("Correlation between Magnetic Field and Calibrated Magnetic Field:")
print(mag_cal_corr)
# Out:
# Correlation between Magnetic Field and Calibrated Magnetic Field:
#              magX(µT)  magY(µT)  magZ(µT)  calMagX(µT)  calMagY(µT)  \
# magX(µT)     1.000000  0.096748 -0.164724     0.905075     0.142761
# magY(µT)     0.096748  1.000000 -0.311112     0.133032     0.972753
# magZ(µT)    -0.164724 -0.311112  1.000000    -0.164947    -0.311364
# calMagX(µT)  0.905075  0.133032 -0.164947     1.000000     0.078793
# calMagY(µT)  0.142761  0.972753 -0.311364     0.078793     1.000000
# calMagZ(µT) -0.070597 -0.320427  0.919903    -0.239861    -0.231057
#
#              calMagZ(µT)
# magX(µT)       -0.070597
# magY(µT)       -0.320427
# magZ(µT)        0.919903
# calMagX(µT)    -0.239861
# calMagY(µT)    -0.231057
# calMagZ(µT)     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix between magnetic field and calibrated magnetic field readings
mag_cal_corr = df_206[['magX(µT)', 'magY(µT)', 'magZ(µT)', 'calMagX(µT)', 'calMagY(µT)', 'calMagZ(µT)']].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(mag_cal_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Magnetic Field and Calibrated Magnetic Field Readings')
plt.show()

# %%
import pandas as pd

#Assuming 'df_206' is your DataFrame containing 'Timestamp' and 'Speed(m/s)' columns
#Convert 'Timestamp' column to datetime format if not already done
df_206['Timestamp'] = pd.to_datetime(df_206['Timestamp'])

#Sort DataFrame by timestamp
df_206.sort_values('Timestamp', inplace=True)

#Calculate change in speed
df_206['Speed_change'] = df_206['Speed(m/s)'].diff()

#Calculate change in time (in seconds)
df_206['Time_change'] = df_206['Timestamp'].diff().dt.total_seconds()

#Compute acceleration
df_206['Acceleration'] = df_206['Speed_change'] / df_206['Time_change']

#Print the DataFrame with acceleration
print(df_206[['Timestamp', 'Speed(m/s)', 'Acceleration']])
# Out:
# <ipython-input-34-db75ba4b3c20>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_206['Timestamp'] = pd.to_datetime(df_206['Timestamp'])
# <ipython-input-34-db75ba4b3c20>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_206.sort_values('Timestamp', inplace=True)
# <ipython-input-34-db75ba4b3c20>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

#Plot acceleration as a function of timestamp, with course as color
scatter = ax1.scatter(df_206['Timestamp'], df_206['Acceleration'], c=df_206['Course'], cmap='viridis')
ax1.set_xlabel('Timestamp')
ax1.set_ylabel('Acceleration (m/s^2)')
ax1.set_title('Acceleration vs Timestamp (Color: Course)')
plt.colorbar(scatter, label='Course')

#Create a secondary y-axis for Alt
ax2 = ax1.twinx()
ax2.set_ylabel('Altitude')

#Plot Alt on the secondary y-axis
scatter_alt = ax2.scatter(df_206['Timestamp'], df_206['Alt(m)'], c=df_206['Course'], cmap='viridis')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'Timestamp' is the name of your timestamp column
df_206['Timestamp'] = pd.to_datetime(df_206['Timestamp'])
df_206.set_index('Timestamp', inplace=True)

# Plot the accelerometer readings over time
plt.figure(figsize=(14, 8))
plt.plot(df_206['accelX(g)'], label='accelX(g)', color='blue')
plt.plot(df_206['accelY(g)'], label='accelY(g)', color='green')
plt.plot(df_206['accelZ(g)'], label='accelZ(g)', color='red')
plt.title('Accelerometer Readings Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Acceleration')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.holtwinters import ExponentialSmoothing


# Decompose the time series into trend, seasonality, and residual components
result = seasonal_decompose(df_206['accelX(g)'], model='additive', period=30)  # Adjust 'period' based on your data
result.plot()
plt.show()

# Plot autocorrelation function (ACF)
plot_acf(df_206['accelX(g)'])
plt.show()

# Time series forecasting using Exponential Smoothing
train_size = int(len(df_206['accelX(g)']) * 0.8)
train, test = df_206['accelX(g)'][:train_size], df_206['accelX(g)'][train_size:]

# Fit an Exponential Smoothing model
model = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=30)  # Adjust 'seasonal_periods' based on your data
model_fit = model.fit()

# Make predictions
predictions = model_fit.predict(start=test.index[0], end=test.index[-1])

# Plot the actual vs. predicted values
plt.figure(figsize=(14, 8))
plt.plot(train.index, train, label='Training Data', color='blue')
plt.plot(test.index, test, label='Test Data', color='green')
plt.plot(predictions.index, predictions, label='Predicted Data', color='red')
plt.title('Exponential Smoothing Forecast')
plt.xlabel('Timestamp')
plt.ylabel('Acceleration')
plt.legend()
plt.show()

# %%
import pandas as pd
#Open ths csv file in read mode
with open('/content/v5_20230407_091351_95m.csv', mode='r')as file:
  df_95=pd.read_csv(file,sep=',')
#print the first five rows of the data
print(df_95.head(5))
# Out:
#                   Timestamp  accelX(g)  accelY(g)  accelZ(g)  accelUserX(g)  \
# 0  07-Apr-2023 09:13:51.953     0.1534    -0.5180    -0.8395        -0.0108
# 1  07-Apr-2023 09:13:52.957     0.1562    -0.5118    -0.8333        -0.0094
# 2  07-Apr-2023 09:13:53.961     0.1508    -0.5035    -0.8493        -0.0059
# 3  07-Apr-2023 09:13:54.965     0.1604    -0.5134    -0.8229        -0.0070
# 4  07-Apr-2023 09:13:55.969     0.1569    -0.5341    -0.8330         0.0065
#
#    accelUserY(g)  accelUserZ(g)  gyroX(rad/s)  gyroY(rad/s)  gyroZ(rad/s)  \
# 0         0.0025        -0.0101        0.0166        0.0051        0.0318
# 1         0.0023         0.0054        0.0042        0.0032       -0.0066
# 2         0.0053        -0.0014        0.0020        0.0021        0.0225
# 3         0.0025         0.0136        0.0594        0.0147        0.0097
# 4        -0.0080         0.0061       -0.0024        0.0176        0.0147
#
# ...

# %%
import pandas as pd

#Assuming 'df_95' is your DataFrame containing 'Timestamp' and 'Speed(m/s)' columns
#Convert 'Timestamp' column to datetime format if not already done
df_95['Timestamp'] = pd.to_datetime(df_95['Timestamp'])

#Sort DataFrame by timestamp
df_95.sort_values('Timestamp', inplace=True)

#Calculate change in speed
df_95['Speed_change'] = df_95['Speed(m/s)'].diff()

#Calculate change in time (in seconds)
df_95['Time_change'] = df_95['Timestamp'].diff().dt.total_seconds()

#Compute acceleration
df_95['Acceleration'] = df_95['Speed_change'] / df_95['Time_change']

#Print the DataFrame with acceleration
print(df_95[['Timestamp', 'Speed(m/s)', 'Acceleration']])
# Out:
#                    Timestamp  Speed(m/s)  Acceleration
# 0    2023-04-07 09:13:51.953      0.1935           NaN
# 1    2023-04-07 09:13:52.957      0.4469      0.252390
# 2    2023-04-07 09:13:53.961      0.2260     -0.220020
# 3    2023-04-07 09:13:54.965      0.5294      0.302191
# 4    2023-04-07 09:13:55.969      0.0000     -0.527291
# ...                      ...         ...           ...
# 5712 2023-04-07 10:49:25.706      1.1109     -0.048904
# 5713 2023-04-07 10:49:26.710      1.0336     -0.076992
# 5714 2023-04-07 10:49:27.713      1.1682      0.134197
# 5715 2023-04-07 10:49:28.717      1.2437      0.075199
# 5716 2023-04-07 10:49:29.721      1.1386     -0.104681
#
# [5717 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 6))

#Plot acceleration as a function of timestamp, with course as color
scatter = ax1.scatter(df_95['Timestamp'], df_95['Acceleration'], c=df_95['Course'], cmap='viridis')
ax1.set_xlabel('Timestamp')
ax1.set_ylabel('Acceleration (m/s^2)')
ax1.set_title('Acceleration vs Timestamp (Color: Course)')
plt.colorbar(scatter, label='Course')

#Create a secondary y-axis for Alt
ax2 = ax1.twinx()
ax2.set_ylabel('Altitude')

#Plot Alt on the secondary y-axis
scatter_alt = ax2.scatter(df_95['Timestamp'], df_95['Alt(m)'], c=df_95['Course'], cmap='viridis')

plt.show()

# %%
import pandas as pd
#Open ths csv file in read mode
with open('/content/v5_20230408_082538_310m.csv', mode='r')as file:
  df_310=pd.read_csv(file,sep=',')
print(df_310.head(5))
