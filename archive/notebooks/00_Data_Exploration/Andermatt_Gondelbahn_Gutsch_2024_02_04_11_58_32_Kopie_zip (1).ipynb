# %%
import pandas as pd

# Replace 'file1.csv', 'file2.csv', etc. with the actual filenames you have
file_paths = ['GyroscopeUncalibrated.csv', 'Accelerometer.csv', 'Metadata.csv', 'Battery.csv', 'Gyroscope.csv', 'Gravity.csv', 'Barometer.csv', 'AccelerometerUncalibrated.csv', 'Location.csv', 'Magnetometer.csv', 'MagnetometerUncalibrated.csv', 'TotalAcceleration.csv', 'Orientation.csv']

# Initialize an empty DataFrame to store the merged data
merged_data1 = pd.DataFrame()

# Loop through each file and append its data to the merged_data DataFrame
for file_path in file_paths:
    # Read the CSV file into a DataFrame
    data = pd.read_csv(file_path)

    # Append the data to the merged_data DataFrame
    merged_data1 = merged_data1.append(data, ignore_index=True)

# Write the merged data to a new CSV file
merged_data1.to_csv('merged_output.csv', index=False)

print("Merged data has been saved to 'merged_output.csv'")
# Out:
# <ipython-input-27-428f344c4607>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data1 = merged_data1.append(data, ignore_index=True)
# <ipython-input-27-428f344c4607>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data1 = merged_data1.append(data, ignore_index=True)
# <ipython-input-27-428f344c4607>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data1 = merged_data1.append(data, ignore_index=True)
# <ipython-input-27-428f344c4607>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data1 = merged_data1.append(data, ignore_index=True)
# ...

# %%
merged_data1.columns
# Out:
# Index(['time', 'seconds_elapsed', 'z', 'y', 'x', 'version', 'device name',
#        'recording epoch time', 'recording time', 'recording timezone',
#        'platform', 'appVersion', 'device id', 'sensors', 'sampleRateMs',
#        'batteryLevel', 'batteryState', 'lowPowerMode', 'relativeAltitude',
#        'pressure', 'bearingAccuracy', 'speedAccuracy', 'verticalAccuracy',
#        'horizontalAccuracy', 'speed', 'bearing', 'altitude', 'longitude',
#        'latitude', 'qz', 'qy', 'qx', 'qw', 'roll', 'pitch', 'yaw'],
#       dtype='object')

# %%
merged_data1
# Out:
#                 time  seconds_elapsed         z         y         x  version  \
# 0       1.707048e+18         0.118568  0.349415  0.276111 -0.822836      NaN
# 1       1.707048e+18         1.068570 -0.113621 -0.276111  1.249219      NaN
# 2       1.707048e+18         2.018572 -0.094073  0.020159 -0.260229      NaN
# 3       1.707048e+18         2.978572 -0.036652 -0.004887  0.124006      NaN
# 4       1.707048e+18         3.938571 -0.017104 -0.055589  0.017104      NaN
# ...              ...              ...       ...       ...       ...      ...
# 157079  1.707062e+18     14581.799305       NaN       NaN       NaN      NaN
# 157080  1.707062e+18     14582.879505       NaN       NaN       NaN      NaN
# 157081  1.707062e+18     14583.959705       NaN       NaN       NaN      NaN
# 157082  1.707062e+18     14585.039804       NaN       NaN       NaN      NaN
# 157083  1.707062e+18     14586.119804       NaN       NaN       NaN      NaN
#
# ...

# %%
merged_data1.to_csv('df_merge.csv',index=True)

# %%
merged_data1.describe()
# Out:
#                time  seconds_elapsed              z              y  \
# count  1.570830e+05    157083.000000  115050.000000  115050.000000
# mean   1.707055e+18      7282.391866     -23.470421       1.037348
# std    4.203621e+12      4203.620521      59.648848      17.193042
# min    1.707048e+18         0.002155    -232.319992    -129.179993
# 25%    1.707052e+18      3643.452889      -3.344063      -8.494514
# 50%    1.707055e+18      7284.566112      -0.039019      -0.032376
# 75%    1.707059e+18     10920.489712       0.701444       3.232883
# max    1.707062e+18     14586.119804      70.559998      86.220001
#
#                    x  version  recording epoch time  appVersion  batteryLevel  \
# count  115050.000000      1.0          1.000000e+00        1.00    126.000000
# mean       -1.801292      3.0          1.707048e+12        1.28      0.926905
# std        11.593726      NaN                   NaN         NaN      0.047505
# ...

# %%
merged_data1.columns
# Out:
# Index(['time', 'seconds_elapsed', 'z', 'y', 'x', 'version', 'device name',
#        'recording epoch time', 'recording time', 'recording timezone',
#        'platform', 'appVersion', 'device id', 'sensors', 'sampleRateMs',
#        'batteryLevel', 'batteryState', 'lowPowerMode', 'relativeAltitude',
#        'pressure', 'bearingAccuracy', 'speedAccuracy', 'verticalAccuracy',
#        'horizontalAccuracy', 'speed', 'bearing', 'altitude', 'longitude',
#        'latitude', 'qz', 'qy', 'qx', 'qw', 'roll', 'pitch', 'yaw'],
#       dtype='object')

# %%
merged_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157084 entries, 0 to 157083
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   time                  157083 non-null  float64
#  1   seconds_elapsed       157083 non-null  float64
#  2   z                     115050 non-null  float64
#  3   y                     115050 non-null  float64
#  4   x                     115050 non-null  float64
#  5   version               1 non-null       float64
#  6   device name           1 non-null       object
#  7   recording epoch time  1 non-null       float64
#  8   recording time        1 non-null       object
#  9   recording timezone    1 non-null       object
#  10  platform              1 non-null       object
#  11  appVersion            1 non-null       float64
#  12  device id             1 non-null       object
#  13  sensors               1 non-null       object
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'merged_data1' is your DataFrame

# Choose the columns you want to plot
columns_to_plot = ['time','seconds_elapsed', 'z', 'y', 'x']

# Plot the selected columns
merged_data1[columns_to_plot].plot(x='time', subplots=True, layout=(2, 3), figsize=(16, 8))
plt.show()

# %%
import pandas as pd

# Drop columns with object data type
merged_data1_clean = merged_data1.select_dtypes(exclude=['object'])

# %%
merged_data1_clean
# Out:
#                 time  seconds_elapsed         z         y         x  version  \
# 0       1.707048e+18         0.118568  0.349415  0.276111 -0.822836      NaN
# 1       1.707048e+18         1.068570 -0.113621 -0.276111  1.249219      NaN
# 2       1.707048e+18         2.018572 -0.094073  0.020159 -0.260229      NaN
# 3       1.707048e+18         2.978572 -0.036652 -0.004887  0.124006      NaN
# 4       1.707048e+18         3.938571 -0.017104 -0.055589  0.017104      NaN
# ...              ...              ...       ...       ...       ...      ...
# 157079  1.707062e+18     14581.799305       NaN       NaN       NaN      NaN
# 157080  1.707062e+18     14582.879505       NaN       NaN       NaN      NaN
# 157081  1.707062e+18     14583.959705       NaN       NaN       NaN      NaN
# 157082  1.707062e+18     14585.039804       NaN       NaN       NaN      NaN
# 157083  1.707062e+18     14586.119804       NaN       NaN       NaN      NaN
#
# ...

# %%
merged_data1_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157084 entries, 0 to 157083
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   time                  157083 non-null  float64
#  1   seconds_elapsed       157083 non-null  float64
#  2   z                     115050 non-null  float64
#  3   y                     115050 non-null  float64
#  4   x                     115050 non-null  float64
#  5   version               1 non-null       float64
#  6   recording epoch time  1 non-null       float64
#  7   appVersion            1 non-null       float64
#  8   batteryLevel          126 non-null     float64
#  9   relativeAltitude      14585 non-null   float64
#  10  pressure              14585 non-null   float64
#  11  bearingAccuracy       13735 non-null   float64
#  12  speedAccuracy         13735 non-null   float64
#  13  verticalAccuracy      13735 non-null   float64
# ...

# %%
# Drop NaN values from the DataFrame
merged_data1_clean = merged_data1.dropna()

# %%
import matplotlib.pyplot as plt

# Assuming 'merged_data1' is your DataFrame

# Choose the columns you want to plot
#columns_to_plot = ['time', 'z', 'y', 'x','qz']
columns_to_plot = ['time','seconds_elapsed', 'z', 'y', 'x']
# Plot the selected columns
merged_data1_clean[columns_to_plot].plot(x='time', subplots=True, layout=(2, 3), figsize=(12, 8))
plt.show()

# %%
import pandas as pd

# Drop columns with object data type
merged_data2_clean = merged_data1.select_dtypes(exclude=['object'])

# %%
merged_data2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157084 entries, 0 to 157083
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   time                  157083 non-null  float64
#  1   seconds_elapsed       157083 non-null  float64
#  2   z                     115050 non-null  float64
#  3   y                     115050 non-null  float64
#  4   x                     115050 non-null  float64
#  5   version               1 non-null       float64
#  6   recording epoch time  1 non-null       float64
#  7   appVersion            1 non-null       float64
#  8   batteryLevel          126 non-null     float64
#  9   relativeAltitude      14585 non-null   float64
#  10  pressure              14585 non-null   float64
#  11  bearingAccuracy       13735 non-null   float64
#  12  speedAccuracy         13735 non-null   float64
#  13  verticalAccuracy      13735 non-null   float64
# ...

# %%
merged_data2_clean
# Out:
#                 time  seconds_elapsed         z         y         x  version  \
# 0       1.707048e+18         0.118568  0.349415  0.276111 -0.822836      NaN
# 1       1.707048e+18         1.068570 -0.113621 -0.276111  1.249219      NaN
# 2       1.707048e+18         2.018572 -0.094073  0.020159 -0.260229      NaN
# 3       1.707048e+18         2.978572 -0.036652 -0.004887  0.124006      NaN
# 4       1.707048e+18         3.938571 -0.017104 -0.055589  0.017104      NaN
# ...              ...              ...       ...       ...       ...      ...
# 157079  1.707062e+18     14581.799305       NaN       NaN       NaN      NaN
# 157080  1.707062e+18     14582.879505       NaN       NaN       NaN      NaN
# 157081  1.707062e+18     14583.959705       NaN       NaN       NaN      NaN
# 157082  1.707062e+18     14585.039804       NaN       NaN       NaN      NaN
# 157083  1.707062e+18     14586.119804       NaN       NaN       NaN      NaN
#
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'merged_data1' is your DataFrame

# Choose the columns you want to plot
#columns_to_plot = ['time', 'z', 'y', 'x','qz']
columns_to_plot = ['time','seconds_elapsed', 'z', 'y', 'x']
# Plot the selected columns
merged_data2_clean[columns_to_plot].plot(x='time', subplots=True, layout=(2, 3), figsize=(12, 8))
plt.show()

# %%
# Drop NaN values from the DataFrame
merged_data3_clean = merged_data1.dropna()

# %%
merged_data3_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  0 non-null      float64
#  1   seconds_elapsed       0 non-null      float64
#  2   z                     0 non-null      float64
#  3   y                     0 non-null      float64
#  4   x                     0 non-null      float64
#  5   version               0 non-null      float64
#  6   device name           0 non-null      object
#  7   recording epoch time  0 non-null      float64
#  8   recording time        0 non-null      object
#  9   recording timezone    0 non-null      object
#  10  platform              0 non-null      object
#  11  appVersion            0 non-null      float64
#  12  device id             0 non-null      object
#  13  sensors               0 non-null      object
#  14  sampleRateMs          0 non-null      object
# ...

# %%
import matplotlib.pyplot as plt



# Choose the columns you want to plot
#columns_to_plot = ['time', 'z', 'y', 'x','qz']
columns_to_plot = ['time','seconds_elapsed', 'z', 'y', 'x']
# Plot the selected columns
merged_data3_clean[columns_to_plot].plot(x='time', subplots=True, layout=(2, 3), figsize=(12, 8))
plt.show()

# %%
import pandas as pd
from zipfile import ZipFile

# Replace 'your_archive.zip' with the actual ZIP file you have
zip_file_path = '/content/Andermatt_Gondelbahn_Gutsch-2024-02-04_11-58-32 - Kopie.zip'

# Initialize an empty DataFrame to store the merged data
merged_data2 = pd.DataFrame()

# Open the ZIP file and loop through each CSV file
with ZipFile(zip_file_path, 'r') as zip_file:
    for file_info in zip_file.infolist():
        with zip_file.open(file_info.filename) as file:
            # Read the CSV file into a DataFrame
            data = pd.read_csv(file)

            # Check if the DataFrame is not empty before appending
            if not data.empty:
                # Append the data to the merged_data DataFrame
                merged_data2 = merged_data2.append(data, ignore_index=True)

# Write the merged data to a new CSV file
merged_data2.to_csv('merged_output.csv', index=False)

print("Merged data has been saved to 'merged_output.csv'")
# Out:
# <ipython-input-13-86793b04c4b9>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data2 = merged_data2.append(data, ignore_index=True)
# <ipython-input-13-86793b04c4b9>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data2 = merged_data2.append(data, ignore_index=True)
# <ipython-input-13-86793b04c4b9>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data2 = merged_data2.append(data, ignore_index=True)
# <ipython-input-13-86793b04c4b9>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data2 = merged_data2.append(data, ignore_index=True)
# ...

# %%
merged_data2

# %%
import pandas as pd
from zipfile import ZipFile

# Replace 'your_archive.zip' with the actual ZIP file you have
zip_file_path = '/content/Andermatt_Gondelbahn_Gutsch-2024-02-04_11-58-32 - Kopie.zip'

# Initialize an empty DataFrame to store the merged data
merged_data3 = pd.DataFrame()

# Loop through each CSV file
with ZipFile(zip_file_path, 'r') as zip_file:
    for file_info in zip_file.infolist():
        with zip_file.open(file_info.filename) as file:
            # Read the CSV file into a DataFrame
            data = pd.read_csv(file)

            # Fill NaN values with zeros
            data = data.fillna(0)

            # Append the data to the merged_data DataFrame
            merged_data3 = merged_data3.append(data, ignore_index=True)


# Write the merged data to a new CSV file
merged_data3.to_csv('merged_output.csv', index=False)

print("Merged data has been saved to 'merged_output.csv'")

# %%
merged_data3

# %%
import pandas as pd
file_paths = ['Accelerometer.csv']
Accelerometer= pd.read_csv(file_path)
Accelerometer

# %%
import pandas as pd
file_paths = ['AccelerometerUncalibrated.csv']
AccelerometerUncalibrated= pd.read_csv(file_path)
AccelerometerUncalibrated

# %%
import pandas as pd
file_paths = ['Barometer.csv']
Barometer= pd.read_csv(file_path)
Barometer

# %%
import pandas as pd
file_paths = ['Barometer.csv']
Barometer= pd.read_csv(file_path)
Barometer

# %%
import pandas as pd
file_paths = ['Battery.csv']
Battery= pd.read_csv(file_path)
Battery

# %%
import pandas as pd
file_paths = ['Gravity.csv']
Gravity= pd.read_csv(file_path)
Gravity

# %%
import pandas as pd
file_paths = ['Gyroscope.csv']
Gyroscope= pd.read_csv(file_path)
Gyroscope

# %%
import pandas as pd
file_paths = ['GyroscopeUncalibrated.csv']
GyroscopeUncalibrated= pd.read_csv(file_path)
GyroscopeUncalibrated

# %%
import pandas as pd
file_paths = ['Location.csv']
Location= pd.read_csv(file_path)
Location

# %%
import pandas as pd
file_paths = ['.csv']
Location= pd.read_csv(file_path)
Location

# %%
import pandas as pd

# List of file paths
file_paths = ['GyroscopeUncalibrated.csv', 'Accelerometer.csv', 'Metadata.csv', 'Battery.csv', 'Gyroscope.csv', 'Gravity.csv', 'Barometer.csv', 'AccelerometerUncalibrated.csv', 'Location.csv', 'Magnetometer.csv', 'MagnetometerUncalibrated.csv', 'TotalAcceleration.csv', 'Orientation.csv']

# Create a dictionary to store DataFrames
data_frames = {}

# Read each CSV file into a DataFrame and store it in the dictionary
for file_path in file_paths:
    data_frames[file_path.split('.')[0]] = pd.read_csv(file_path)

# Access the DataFrames using keys (file names without the extension)
gyroscope_uncalibrated_data = data_frames['GyroscopeUncalibrated']
accelerometer_data = data_frames['Accelerometer']
metadata_data = data_frames['Metadata']
battery_data = data_frames['Battery']
gyroscope_data = data_frames['Gyroscope']
gravity_data = data_frames['Gravity']
barometer_data = data_frames['Barometer']
accelerometer_uncalibrated_data = data_frames['AccelerometerUncalibrated']
location_data = data_frames['Location']
magnetometer_data = data_frames['Magnetometer']
magnetometer_uncalibrated_data = data_frames['MagnetometerUncalibrated']
total_acceleration_data = data_frames['TotalAcceleration']
orientation_data = data_frames['Orientation']

# You can now work with each DataFrame as needed

# %%
magnetometer_data

# %%
magnetometer_uncalibrated_data

# %%
total_acceleration_data

# %%
orientation_data

# %%
import pandas as pd

# List of file paths
file_paths = ['GyroscopeUncalibrated.csv', 'Accelerometer.csv', 'Metadata.csv', 'Battery.csv', 'Gyroscope.csv', 'Gravity.csv', 'Barometer.csv', 'AccelerometerUncalibrated.csv', 'Location.csv', 'Magnetometer.csv', 'MagnetometerUncalibrated.csv', 'TotalAcceleration.csv', 'Orientation.csv']

# Create a dictionary to store DataFrames
data_frames = {}

# Read each CSV file into a DataFrame and store it in the dictionary
for file_path in file_paths:
    data_frames[file_path.split('.')[0]] = pd.read_csv(file_path)

# Choose a common identifier for merging, for example, 'time' assuming it exists in all DataFrames
common_identifier = 'time'

# Perform a left merge on the first two DataFrames
merged_data = pd.merge(data_frames['GyroscopeUncalibrated'], data_frames['Accelerometer'], on=common_identifier, how='left')

# Iterate through the rest of the DataFrames and merge with the previously merged DataFrame
for key in data_frames.keys():
    if key not in ['GyroscopeUncalibrated', 'Accelerometer']:
        merged_data = pd.merge(merged_data, data_frames[key], on=common_identifier, how='left')

# You can now work with the merged DataFrame
# The merged DataFrame will have a column for the common identifier ('time' in this case) and all columns from the original DataFrames

# %%
import pandas as pd

# List of file paths
file_paths = ['GyroscopeUncalibrated.csv', 'Accelerometer.csv', 'Metadata.csv', 'Battery.csv', 'Gyroscope.csv', 'Gravity.csv', 'Barometer.csv', 'AccelerometerUncalibrated.csv', 'Location.csv', 'Magnetometer.csv', 'MagnetometerUncalibrated.csv', 'TotalAcceleration.csv', 'Orientation.csv']

# Create a dictionary to store DataFrames
data_frames = {}

# Read each CSV file into a DataFrame and store it in the dictionary
for file_path in file_paths:
    data_frames[file_path.split('.')[0]] = pd.read_csv(file_path)

# Identify a common identifier present in all DataFrames
common_identifier = None
for key, df in data_frames.items():
    common_columns = set(df.columns) & set(data_frames['GyroscopeUncalibrated'].columns)
    if common_columns:
        common_identifier = common_columns.pop()
        break

if common_identifier is not None:
    # Perform a left merge on the first two DataFrames
    merged_data = pd.merge(data_frames['GyroscopeUncalibrated'], data_frames['Accelerometer'], on=common_identifier, how='left')

    # Iterate through the rest of the DataFrames and merge with the previously merged DataFrame
    for key in data_frames.keys():
        if key not in ['GyroscopeUncalibrated', 'Accelerometer']:
            merged_data = pd.merge(merged_data, data_frames[key], on=common_identifier, how='left')

    # You can now work with the merged DataFrame
    # The merged DataFrame will have a column for the common identifier and all columns from the original DataFrames
else:
    print("No common identifier found. Consider exploring other merging strategies.")

# %%
import pandas as pd

# List of file paths
file_paths = ['GyroscopeUncalibrated.csv', 'Accelerometer.csv', 'Metadata.csv', 'Battery.csv', 'Gyroscope.csv', 'Gravity.csv', 'Barometer.csv', 'AccelerometerUncalibrated.csv', 'Location.csv', 'Magnetometer.csv', 'MagnetometerUncalibrated.csv', 'TotalAcceleration.csv', 'Orientation.csv']

# Create a dictionary to store DataFrames
data_frames = {}

# Read each CSV file into a DataFrame and store it in the dictionary
for file_path in file_paths:
    data_frames[file_path.split('.')[0]] = pd.read_csv(file_path)

# Manually choose a common column present in all DataFrames
common_column = 'your_chosen_column'  # Replace with an actual common column

if common_column in data_frames['GyroscopeUncalibrated'].columns:
    # Perform a left merge on the first two DataFrames
    merged_data = pd.merge(data_frames['GyroscopeUncalibrated'], data_frames['Accelerometer'], on=common_column, how='left')

    # Iterate through the rest of the DataFrames and merge with the previously merged DataFrame
    for key in data_frames.keys():
        if key not in ['GyroscopeUncalibrated', 'Accelerometer']:
            merged_data = pd.merge(merged_data, data_frames[key], on=common_column, how='left')

    # You can now work with the merged DataFrame
    # The merged DataFrame will have a column for the common column and all columns from the original DataFrames
else:
    print(f"The column '{common_column}' is not present in 'GyroscopeUncalibrated'. Choose another common column.")

# %%
data_frames

# %%
import pandas as pd

# List of file paths
file_paths = ['GyroscopeUncalibrated.csv', 'Accelerometer.csv', 'Metadata.csv', 'Battery.csv', 'Gyroscope.csv', 'Gravity.csv', 'Barometer.csv', 'AccelerometerUncalibrated.csv', 'Location.csv', 'Magnetometer.csv', 'MagnetometerUncalibrated.csv', 'TotalAcceleration.csv', 'Orientation.csv']

# Create a dictionary to store DataFrames
data_frames = {}

# Read each CSV file into a DataFrame and store it in the dictionary
for file_path in file_paths:
    data_frames[file_path.split('.')[0]] = pd.read_csv(file_path)

# Manually choose a common column present in all DataFrames
common_column = 'your_chosen_column'  # Replace with an actual common column

if common_column in data_frames['GyroscopeUncalibrated'].columns:
    # Perform a left merge on the first two DataFrames
    merged_data = pd.merge(data_frames['GyroscopeUncalibrated'], data_frames['Accelerometer'], on=common_column, how='left')

    # Iterate through the rest of the DataFrames and merge with the previously merged DataFrame
    for key in data_frames.keys():
        if key not in ['GyroscopeUncalibrated', 'Accelerometer']:
            merged_data = pd.merge(merged_data, data_frames[key], on=common_column, how='left')

    # Drop NaN values from the merged DataFrame
    merged_data = merged_data.dropna()

    # You can now work with the cleaned merged DataFrame
    # The cleaned DataFrame will have no NaN values
else:
    print(f"The column '{common_column}' is not present in 'GyroscopeUncalibrated'. Choose another common column.")

# %%
from datetime import datetime

timestamp = 1707149961
dt_object = datetime.utcfromtimestamp(timestamp)

print("UTC Time:", dt_object.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# UTC Time: 2024-02-05 16:19:21

# %%
pip install pandas pytz

# %%
import pandas as pd
from datetime import datetime
from pytz import timezone  # Requires the pytz library

# Read the CSV file into a DataFrame
df = pd.read_csv('/content/df_merge.csv')

# Assuming your CSV column is named 'utc_time'
df['time'] = pd.to_datetime(df['time'], unit='s')  # Assuming the time is stored as Unix timestamps

# Set the time zone to UTC
df['time'] = df['utc_time'].dt.tz_localize('UTC')

# Convert to a specific local time zone (e.g., 'America/New_York')
local_time_zone = timezone('America/New_York')
df['local_time'] = df['time'].dt.tz_convert(local_time_zone)

# If you want to save the updated DataFrame to a new CSV file
df.to_csv('converted_file.csv', index=False)
